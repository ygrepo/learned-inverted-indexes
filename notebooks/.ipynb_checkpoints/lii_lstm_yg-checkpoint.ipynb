# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
# Set up device and manual seed
torch.manual_seed(1)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# Create data
x = torch.arange(500, out=torch.FloatTensor()).view((-1, 1))
inverted_index = torch.randperm(1000, out=torch.FloatTensor())[:500].view(-1, 1, 1)
print(inverted_index.shape)
print(inverted_index[:2,:])
inverted_index = torch.sort(inverted_index, dim=0)
inverted_index = inverted_index[0]
max_document = inverted_index.max()
inverted_index_scaled = inverted_index / max_document
print(inverted_index_scaled.shape)
# Out:
# torch.Size([500, 1, 1])
# tensor([[[845.]],
#
#         [[303.]]])
# torch.Size([500, 1, 1])

# %%
inverted_index[:2,:]
# Out:
# tensor([[[0.]],
#
#         [[2.]]])

# %%
from sklearn.preprocessing import StandardScaler
y = StandardScaler().fit_transform(inverted_index.reshape(-1, 1).numpy())
y = torch.from_numpy(y)

# %%
inverted_index_scaled.shape
# Out:
# torch.Size([500, 1, 1])

# %%
y.shape
# Out:
# torch.Size([500, 1])

# %%
x[:2,:]
# Out:
# tensor([[0.],
#         [1.]])

# %%
class LII_LSTM(nn.Module):
    def __init__(self, input_size=1, hidden_size=10, num_layers=1):
        super(LII_LSTM, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(self.input_size, self.hidden_size)
        self.linear = nn.Linear(self.hidden_size, 1)  # output size is 1
    
    def forward(self, input_seq):
        lstm_out, _ = self.lstm(input_seq.view(input_seq.size()[0], 1, 1))
        index_out = self.linear(lstm_out)
        return index_out

# %%
def train(model, optimizer, index, target, scheduler=None, epochs=2000):
    index.to(device)
    target.to(device)
    model.train()
    for e in range(1, epochs+1):
        # Zero out the grad
        optimizer.zero_grad()

        # Get output
        prediction = model(index)
        loss = F.mse_loss(prediction, target)
        
        # Take gradient step
        loss.backward()
        optimizer.step()
        
        # Take scheduler step
        if scheduler:
            scheduler.step(loss)
        
        # Print loss
        if e % 50 == 0:
        #if e % 200 == 0:
            with torch.no_grad():
                plot_pred = prediction.detach().numpy().reshape(-1)
                plot_index = index.numpy().reshape(-1)
                plot_target = target.numpy().reshape(-1)
                error = target - prediction
                max_error = abs(error.max().item())
            title = "Train Epoch {}: Loss - {}; Max error - {}".format(e, loss.item(), max_error)
            plt.plot(plot_index, plot_target, label="True")
            plt.plot(plot_index, plot_pred, label="Prediction")
            plt.title(title)
            plt.legend(loc="best")
            plt.show()
    return prediction

# %%
# # Create model and setup optimizer
# lii_lstm = LII_LSTM()
# lii_lstm.to(device)
# optimizer = optim.Adam(params=lii_lstm.parameters(), lr=0.01)

# %%
# Train model on unscaled inverted indices
# prediction = train(lii_lstm, optimizer, x, inverted_index)

# %%
# Compare prediction and ground truth
# for i in range(prediction.size()[0]):
#     print("True value: {} vs. Predicted: {}".format(int(inverted_index[i].item()),
#                                                     int(round(prediction[i].item()))))

# %%
# Train model on scaled inverted indices
lii_lstm = LII_LSTM()
lii_lstm.to(device)
optimizer = optim.Adam(params=lii_lstm.parameters(), lr=0.01)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=20, verbose=True, threshold=10e-6)
prediction_scaled = train(lii_lstm, optimizer, x, inverted_index_scaled, scheduler, epochs=500)
# Out:
# Epoch   411: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   432: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   453: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   474: reducing learning rate of group 0 to 1.0000e-06.
# Epoch   495: reducing learning rate of group 0 to 1.0000e-07.

# %%
# Compare prediction and ground truth
for i in range(prediction_scaled.size()[0]):
    print("True value: {} vs. Predicted: {}".format(int((inverted_index_scaled[i].item()*max_document).round()), 
                                                    int((prediction_scaled[i].item()*max_document).round())))
# Out:
# True value: 4 vs. Predicted: 3
# True value: 5 vs. Predicted: 3
# True value: 6 vs. Predicted: 9
# True value: 7 vs. Predicted: 11
# True value: 8 vs. Predicted: 7
# True value: 9 vs. Predicted: 5
# True value: 10 vs. Predicted: 5
# True value: 12 vs. Predicted: 7
# True value: 15 vs. Predicted: 10
# True value: 17 vs. Predicted: 13
# True value: 18 vs. Predicted: 17
# True value: 19 vs. Predicted: 20
# True value: 20 vs. Predicted: 24
# True value: 22 vs. Predicted: 27
# True value: 23 vs. Predicted: 30
# True value: 24 vs. Predicted: 33
# True value: 25 vs. Predicted: 36
# True value: 27 vs. Predicted: 38
# True value: 28 vs. Predicted: 41
# True value: 29 vs. Predicted: 43
# True value: 31 vs. Predicted: 45
# True value: 32 vs. Predicted: 47
# True value: 35 vs. Predicted: 49
# True value: 40 vs. Predicted: 51
# True value: 43 vs. Predicted: 53
# True value: 46 vs. Predicted: 55
# True value: 48 vs. Predicted: 57
# True value: 49 vs. Predicted: 58
# True value: 50 vs. Predicted: 60
# True value: 51 vs. Predicted: 62
# True value: 58 vs. Predicted: 63
# True value: 59 vs. Predicted: 65
# True value: 60 vs. Predicted: 66
# True value: 61 vs. Predicted: 68
# True value: 62 vs. Predicted: 69
# True value: 64 vs. Predicted: 71
# True value: 65 vs. Predicted: 72
# True value: 66 vs. Predicted: 74
# True value: 69 vs. Predicted: 75
# True value: 70 vs. Predicted: 77
# True value: 71 vs. Predicted: 78
# True value: 73 vs. Predicted: 79
# True value: 74 vs. Predicted: 81
# True value: 75 vs. Predicted: 82
# True value: 76 vs. Predicted: 84
# True value: 78 vs. Predicted: 85
# True value: 80 vs. Predicted: 87
# True value: 87 vs. Predicted: 88
# True value: 89 vs. Predicted: 90
# True value: 91 vs. Predicted: 91
# True value: 92 vs. Predicted: 93
# True value: 94 vs. Predicted: 94
# True value: 96 vs. Predicted: 96
# True value: 97 vs. Predicted: 97
# True value: 98 vs. Predicted: 99
# True value: 100 vs. Predicted: 101
# True value: 105 vs. Predicted: 102
# True value: 106 vs. Predicted: 104
# True value: 109 vs. Predicted: 105
# True value: 110 vs. Predicted: 107
# True value: 111 vs. Predicted: 109
# True value: 113 vs. Predicted: 110
# True value: 114 vs. Predicted: 112
# True value: 117 vs. Predicted: 114
# True value: 121 vs. Predicted: 115
# True value: 122 vs. Predicted: 117
# True value: 127 vs. Predicted: 119
# True value: 128 vs. Predicted: 120
# True value: 129 vs. Predicted: 122
# True value: 130 vs. Predicted: 124
# True value: 131 vs. Predicted: 125
# True value: 132 vs. Predicted: 127
# True value: 134 vs. Predicted: 129
# True value: 137 vs. Predicted: 131
# True value: 139 vs. Predicted: 132
# True value: 142 vs. Predicted: 134
# True value: 143 vs. Predicted: 136
# True value: 662 vs. Predicted: 659
# True value: 663 vs. Predicted: 662
# True value: 666 vs. Predicted: 664
# True value: 667 vs. Predicted: 666
# True value: 669 vs. Predicted: 668
# True value: 672 vs. Predicted: 670
# True value: 677 vs. Predicted: 673
# True value: 678 vs. Predicted: 675
# True value: 682 vs. Predicted: 677
# True value: 686 vs. Predicted: 679
# True value: 687 vs. Predicted: 682
# True value: 688 vs. Predicted: 684
# True value: 689 vs. Predicted: 686
# True value: 690 vs. Predicted: 688
# True value: 692 vs. Predicted: 691
# True value: 694 vs. Predicted: 693
# True value: 695 vs. Predicted: 695
# True value: 697 vs. Predicted: 697
# True value: 700 vs. Predicted: 700
# True value: 701 vs. Predicted: 702
# True value: 703 vs. Predicted: 704
# True value: 704 vs. Predicted: 706
# True value: 705 vs. Predicted: 708
# True value: 706 vs. Predicted: 711
# True value: 707 vs. Predicted: 713
# True value: 708 vs. Predicted: 715
# True value: 709 vs. Predicted: 717
# True value: 710 vs. Predicted: 719
# True value: 714 vs. Predicted: 722
# True value: 715 vs. Predicted: 724
# True value: 717 vs. Predicted: 726
# True value: 718 vs. Predicted: 728
# True value: 719 vs. Predicted: 730
# True value: 721 vs. Predicted: 732
# True value: 722 vs. Predicted: 735
# True value: 724 vs. Predicted: 737
# True value: 726 vs. Predicted: 739
# True value: 727 vs. Predicted: 741
# True value: 728 vs. Predicted: 743
# True value: 729 vs. Predicted: 745
# True value: 730 vs. Predicted: 748
# True value: 733 vs. Predicted: 750
# True value: 734 vs. Predicted: 752
# True value: 738 vs. Predicted: 754
# True value: 739 vs. Predicted: 756
# True value: 745 vs. Predicted: 758
# True value: 746 vs. Predicted: 760
# True value: 748 vs. Predicted: 762
# True value: 749 vs. Predicted: 765
# True value: 751 vs. Predicted: 767
# True value: 752 vs. Predicted: 769
# True value: 753 vs. Predicted: 771
# True value: 757 vs. Predicted: 773
# True value: 758 vs. Predicted: 775
# True value: 759 vs. Predicted: 777
# True value: 760 vs. Predicted: 779
# True value: 761 vs. Predicted: 781
# True value: 763 vs. Predicted: 783
# True value: 767 vs. Predicted: 785
# True value: 770 vs. Predicted: 787
# True value: 772 vs. Predicted: 789
# True value: 774 vs. Predicted: 791
# True value: 778 vs. Predicted: 793
# True value: 782 vs. Predicted: 795
# True value: 783 vs. Predicted: 797
# True value: 785 vs. Predicted: 799
# True value: 786 vs. Predicted: 801
# True value: 787 vs. Predicted: 803
# True value: 788 vs. Predicted: 805
# True value: 789 vs. Predicted: 807
# True value: 790 vs. Predicted: 809
# True value: 791 vs. Predicted: 811
# True value: 792 vs. Predicted: 813
# True value: 793 vs. Predicted: 815
# True value: 795 vs. Predicted: 817
# True value: 798 vs. Predicted: 819
# True value: 799 vs. Predicted: 821
# True value: 801 vs. Predicted: 823
# True value: 805 vs. Predicted: 825
# True value: 807 vs. Predicted: 827
# True value: 811 vs. Predicted: 829
# True value: 812 vs. Predicted: 831
# True value: 813 vs. Predicted: 832
# True value: 817 vs. Predicted: 834
