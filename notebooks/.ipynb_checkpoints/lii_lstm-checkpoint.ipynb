# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
# Set up device and manual seed
torch.manual_seed(1)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# Create data
x = torch.arange(500, out=torch.FloatTensor()).view((-1, 1))
inverted_index = torch.randperm(1000, out=torch.FloatTensor())[:500].view(-1, 1, 1)
inverted_index = torch.sort(inverted_index, dim=0)
inverted_index = inverted_index[0]
max_document = inverted_index.max()
inverted_index_scaled = inverted_index / max_document

# %%
class LII_LSTM(nn.Module):
    def __init__(self, input_size=1, hidden_size=10, num_layers=1):
        super(LII_LSTM, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(self.input_size, self.hidden_size)
        self.linear = nn.Linear(self.hidden_size, 1)  # output size is 1
    
    def forward(self, input_seq):
        lstm_out, _ = self.lstm(input_seq.view(input_seq.size()[0], 1, 1))
        index_out = self.linear(lstm_out)
        return index_out

# %%
def train(model, optimizer, index, target, scheduler=None, epochs=2000):
    index.to(device)
    target.to(device)
    model.train()
    for e in range(1, epochs+1):
        # Zero out the grad
        optimizer.zero_grad()

        # Get output
        prediction = model(index)
        loss = F.mse_loss(prediction, target)
        
        # Take gradient step
        loss.backward()
        optimizer.step()
        
        # Take scheduler step
        if scheduler:
            scheduler.step(loss)
        
        # Print loss
        if e % 200 == 0:
            with torch.no_grad():
                plot_pred = prediction.detach().numpy().reshape(-1)
                plot_index = index.numpy().reshape(-1)
                plot_target = target.numpy().reshape(-1)
                error = target - prediction
                max_error = abs(error.max().item())
            title = "Train Epoch {}: Loss - {}; Max error - {}".format(e, loss.item(), max_error)
            plt.plot(plot_index, plot_target, label="True")
            plt.plot(plot_index, plot_pred, label="Prediction")
            plt.title(title)
            plt.legend(loc="best")
            plt.show()
    return prediction

# %%
# # Create model and setup optimizer
# lii_lstm = LII_LSTM()
# lii_lstm.to(device)
# optimizer = optim.Adam(params=lii_lstm.parameters(), lr=0.01)

# %%
# Train model on unscaled inverted indices
# prediction = train(lii_lstm, optimizer, x, inverted_index)

# %%
# Compare prediction and ground truth
# for i in range(prediction.size()[0]):
#     print("True value: {} vs. Predicted: {}".format(int(inverted_index[i].item()),
#                                                     int(round(prediction[i].item()))))

# %%
# Train model on scaled inverted indices
lii_lstm = LII_LSTM()
lii_lstm.to(device)
optimizer = optim.Adam(params=lii_lstm.parameters(), lr=0.01)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=20, verbose=True, threshold=10e-6)
prediction_scaled = train(lii_lstm, optimizer, x, inverted_index_scaled, scheduler)
# Out:
# Epoch   194: reducing learning rate of group 0 to 1.0000e-03.

# %%
# Compare prediction and ground truth
for i in range(prediction_scaled.size()[0]):
    print("True value: {} vs. Predicted: {}".format(int((inverted_index_scaled[i].item()*max_document).round()), 
                                                    int((prediction_scaled[i].item()*max_document).round())))
# Out:
# True value: 1 vs. Predicted: 5
# True value: 2 vs. Predicted: -5
# True value: 3 vs. Predicted: 7
# True value: 7 vs. Predicted: 9
# True value: 10 vs. Predicted: 9
# True value: 12 vs. Predicted: 10
# True value: 15 vs. Predicted: 13
# True value: 16 vs. Predicted: 17
# True value: 19 vs. Predicted: 20
# True value: 21 vs. Predicted: 23
# True value: 25 vs. Predicted: 25
# True value: 27 vs. Predicted: 28
# True value: 30 vs. Predicted: 30
# True value: 33 vs. Predicted: 32
# True value: 34 vs. Predicted: 34
# True value: 38 vs. Predicted: 37
# True value: 40 vs. Predicted: 39
# True value: 43 vs. Predicted: 41
# True value: 44 vs. Predicted: 43
# True value: 45 vs. Predicted: 45
# True value: 46 vs. Predicted: 47
# True value: 47 vs. Predicted: 49
# True value: 50 vs. Predicted: 51
# True value: 51 vs. Predicted: 53
# True value: 53 vs. Predicted: 55
# True value: 57 vs. Predicted: 57
# True value: 60 vs. Predicted: 58
# True value: 61 vs. Predicted: 60
# True value: 62 vs. Predicted: 62
# True value: 64 vs. Predicted: 63
# True value: 65 vs. Predicted: 65
# True value: 66 vs. Predicted: 67
# True value: 68 vs. Predicted: 68
# True value: 70 vs. Predicted: 70
# True value: 71 vs. Predicted: 72
# True value: 75 vs. Predicted: 74
# True value: 77 vs. Predicted: 76
# True value: 78 vs. Predicted: 77
# True value: 79 vs. Predicted: 79
# True value: 81 vs. Predicted: 81
# True value: 85 vs. Predicted: 83
# True value: 86 vs. Predicted: 85
# True value: 87 vs. Predicted: 87
# True value: 89 vs. Predicted: 89
# True value: 90 vs. Predicted: 91
# True value: 91 vs. Predicted: 94
# True value: 94 vs. Predicted: 96
# True value: 95 vs. Predicted: 98
# True value: 99 vs. Predicted: 100
# True value: 105 vs. Predicted: 102
# True value: 106 vs. Predicted: 104
# True value: 107 vs. Predicted: 106
# True value: 108 vs. Predicted: 109
# True value: 110 vs. Predicted: 111
# True value: 114 vs. Predicted: 113
# True value: 115 vs. Predicted: 115
# True value: 117 vs. Predicted: 117
# True value: 118 vs. Predicted: 119
# True value: 123 vs. Predicted: 121
# True value: 124 vs. Predicted: 123
# True value: 125 vs. Predicted: 125
# True value: 128 vs. Predicted: 127
# True value: 129 vs. Predicted: 129
# True value: 130 vs. Predicted: 131
# True value: 132 vs. Predicted: 133
# True value: 134 vs. Predicted: 134
# True value: 135 vs. Predicted: 136
# True value: 137 vs. Predicted: 138
# True value: 138 vs. Predicted: 139
# True value: 140 vs. Predicted: 141
# True value: 142 vs. Predicted: 143
# True value: 143 vs. Predicted: 144
# True value: 147 vs. Predicted: 146
# True value: 148 vs. Predicted: 147
# True value: 151 vs. Predicted: 149
# True value: 152 vs. Predicted: 151
# True value: 153 vs. Predicted: 152
# True value: 155 vs. Predicted: 154
# True value: 156 vs. Predicted: 156
# True value: 157 vs. Predicted: 157
# True value: 159 vs. Predicted: 159
# True value: 160 vs. Predicted: 161
# True value: 161 vs. Predicted: 162
# True value: 162 vs. Predicted: 164
# True value: 163 vs. Predicted: 166
# True value: 164 vs. Predicted: 168
# True value: 165 vs. Predicted: 170
# True value: 169 vs. Predicted: 171
# True value: 170 vs. Predicted: 173
# True value: 171 vs. Predicted: 175
# True value: 176 vs. Predicted: 177
# True value: 182 vs. Predicted: 179
